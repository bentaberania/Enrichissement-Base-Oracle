# %% [markdown]
# ## ------------------------------------------
# ## SCRIPT DE TRAITEMENT DE LA BASE DE DONNÉES KAGGLE (CleansingWine.csv)
# ### Objectif : nettoyer, compléter et structurer les données pour insertion dans Oracle
# ### Tables cibles : VINR, PRODUCTEURR, RECOLTER
# ## ------------------------------------------

# %% [markdown]
# ### Installation des bibliothèques nécessaires :
# #### pandas      → pour manipuler les données tabulaires (DataFrame)
# #### numpy       → pour les opérations numériques (ex : NaN, conditions)
# #### faker       → pour générer des prénoms aléatoires réalistes
# #### googletrans → pour traduire automatiquement les noms de régions

# %%
pip install pandas numpy faker googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.11/site-packages (2.0.3)
# Requirement already satisfied: numpy in /opt/anaconda3/lib/python3.11/site-packages (1.24.3)
# Requirement already satisfied: faker in /opt/anaconda3/lib/python3.11/site-packages (37.1.0)
# Requirement already satisfied: googletrans==4.0.0-rc1 in /opt/anaconda3/lib/python3.11/site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /opt/anaconda3/lib/python3.11/site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.2.2)
# Requirement already satisfied: hstspreload in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Requirement already satisfied: chardet==3.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from faker import Faker
from googletrans import Translator

# %% [markdown]
# ### 1. Chargement et aperçu des données

# %%
df = pd.read_csv("cleansingWine.csv")
df.head(10)
# Out:
# /tmp/ipykernel_5154/1664116324.py:1: DtypeWarning: Columns (8,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("cleansingWine.csv")
#    Unnamed: 0      id                                  name      producer  \
# 0           0  137197                                Altair        Altair
# 1           1  137198                       Altair, Sideral        Altair
# 2           2  137199                      Baron du Val Red  Baron du Val
# 3           3  137200                    Baron du Val White  Baron du Val
# 4           4  137201          Benziger, Cabernet Sauvignon      Benziger
# 5           5  137202           Calvet, Beaujolais Villages        Calvet
# 6           6  137203                         Calvet, Aetos        Calvet
# 7           7  137204                  Calvet, Bordeaux Red        Calvet
# 8           8  137205                Calvet, Bordeaux white        Calvet
# 9           9  137207  Calvet, Varietals Cabernet Sauvignon        Calvet
#
#    nation           local1                local2 local3 local4  \
# 0   Chile     Rapel Valley                   NaN    NaN    NaN
# 1   Chile     Rapel Valley                   NaN    NaN    NaN
# 2  France              NaN                   NaN    NaN    NaN
# 3  France              NaN                   NaN    NaN    NaN
# 4     USA       California                   NaN    NaN    NaN
# 5  France        Bourgogne            Beaujolais    NaN    NaN
# 6  France         Bordeaux                   NaN    NaN    NaN
# 7  France         Bordeaux                   NaN    NaN    NaN
# 8  France         Bordeaux                   NaN    NaN    NaN
# 9  France  Southern France  Languedoc Roussillon    NaN    NaN
#
#            varieties1  ...    use    abv degree   sweet   acidity   body  \
# 0  Cabernet Sauvignon  ...  Table  14~15  17~19  SWEET1  ACIDITY4  BODY5
# 1  Cabernet Sauvignon  ...  Table  14~15  16~18  SWEET1  ACIDITY3  BODY4
# 2            Carignan  ...  Table  11~12  15~17  SWEET2  ACIDITY3  BODY2
# 3            Carignan  ...  Table  11~12   9~11  SWEET1  ACIDITY3  BODY2
# 4  Cabernet Sauvignon  ...  Table  13~14  17~19  SWEET1  ACIDITY3  BODY3
# 5               Gamay  ...  Table     12  13~15  SWEET2  ACIDITY4  BODY2
# 6              Merlot  ...  Table     13  17~19  SWEET1  ACIDITY3  BODY4
# 7              Merlot  ...  Table  13~14  16~18  SWEET1  ACIDITY3  BODY2
# 8     Sauvignon blanc  ...  Table   11.5   9~11  SWEET1  ACIDITY4  BODY2
# 9  Cabernet Sauvignon  ...  Table  13~14  16~18  SWEET1  ACIDITY3  BODY2
#
#     tannin   price  year   ml
# 0  TANNIN4  220000  2014  750
# 1  TANNIN4  110000  2016  750
# 2  TANNIN2       0     0  750
# 3  TANNIN1       0     0  750
# 4  TANNIN4       0  2003  750
# 5  TANNIN2       0  2007  750
# 6  TANNIN3       0  2003  750
# 7  TANNIN3   21000  2011  750
# 8  TANNIN1   21000  2010  750
# 9  TANNIN3   19000  2017  750
#
# [10 rows x 32 columns]

# %% [markdown]
# ### 2. Suppression des colonnes inutiles

# %%
colonnes_a_supprimer = [
    'Unnamed: 0', 'nation', 'local2', 'local3', 'local4', 'varieties1', 'varieties2',
    'use', 'degree', 'sweet', 'acidity', 'tannin', 'price', 'body', 'varieties3',
    'varieties4', 'varieties5', 'varieties6', 'varieties7', 'varieties8', 'varieties9',
    'varieties10', 'varieties11', 'varieties12', 'type'
]
df.drop(columns=colonnes_a_supprimer, inplace=True)
df.head(20)
# Out:
#         id                                  name  \
# 0   137197                                Altair
# 1   137198                       Altair, Sideral
# 2   137199                      Baron du Val Red
# 3   137200                    Baron du Val White
# 4   137201          Benziger, Cabernet Sauvignon
# 5   137202           Calvet, Beaujolais Villages
# 6   137203                         Calvet, Aetos
# 7   137204                  Calvet, Bordeaux Red
# 8   137205                Calvet, Bordeaux white
# 9   137207  Calvet, Varietals Cabernet Sauvignon
# 10  137208              Calvet, Varietals Merlot
# 11  137209        Calvet, Reserve Bordeaux white
# 12  137210   Calvet, Premieres Cotes de Bordeaux
# 13  137211                       Calvet, Margaux
# 14  137212                         Calvet, Medoc
# 15  137214                 Calvet, Saint Emilion
# 16  137217           Tavernello Rosato Frizzante
# 17  137218            Tavernello Bianco Fizzante
# 18  137222              La Carillon de l'Angelus
# 19  137224                     Chateau Brillette
#
#                                  producer           local1    abv  year   ml
# 0                                  Altair     Rapel Valley  14~15  2014  750
# 1                                  Altair     Rapel Valley  14~15  2016  750
# 2                            Baron du Val              NaN  11~12     0  750
# 3                            Baron du Val              NaN  11~12     0  750
# 4                                Benziger       California  13~14  2003  750
# 5                                  Calvet        Bourgogne     12  2007  750
# 6                                  Calvet         Bordeaux     13  2003  750
# 7                                  Calvet         Bordeaux  13~14  2011  750
# 8                                  Calvet         Bordeaux   11.5  2010  750
# 9                                  Calvet  Southern France  13~14  2017  750
# 10                                 Calvet  Southern France  13~14  2011  750
# 11                                 Calvet         Bordeaux   11.5  2011  750
# 12                                 Calvet         Bordeaux     13  2009  750
# 13                                 Calvet         Bordeaux   12.5  2004  750
# 14                                 Calvet         Bordeaux  12~13  2015  750
# 15                                 Calvet         Bordeaux  12~13  2010  750
# 16                        Caviro scaForli    EmiliaRomagna     11     0  750
# 17                        Caviro scaForli    EmiliaRomagna     11     0  750
# 18  Chateau Angelus 1st Grand Cru ClasseA         Bordeaux   13.5  2017  750
# 19                      Chateau Brillette         Bordeaux  13~14  2013  750

# %% [markdown]
# ### 3. Renommage des colonnes principales

# %%
df = df.rename(columns={'id': 'Nvin', 'name': 'Cru', 'producer': 'Nom', 'local1': 'Region', 'abv': 'Degre', 'year': 'Annee', 'ml': 'Qte'})
df.head(20)
# Out:
#       Nvin                                   Cru  \
# 0   137197                                Altair
# 1   137198                       Altair, Sideral
# 2   137199                      Baron du Val Red
# 3   137200                    Baron du Val White
# 4   137201          Benziger, Cabernet Sauvignon
# 5   137202           Calvet, Beaujolais Villages
# 6   137203                         Calvet, Aetos
# 7   137204                  Calvet, Bordeaux Red
# 8   137205                Calvet, Bordeaux white
# 9   137207  Calvet, Varietals Cabernet Sauvignon
# 10  137208              Calvet, Varietals Merlot
# 11  137209        Calvet, Reserve Bordeaux white
# 12  137210   Calvet, Premieres Cotes de Bordeaux
# 13  137211                       Calvet, Margaux
# 14  137212                         Calvet, Medoc
# 15  137214                 Calvet, Saint Emilion
# 16  137217           Tavernello Rosato Frizzante
# 17  137218            Tavernello Bianco Fizzante
# 18  137222              La Carillon de l'Angelus
# 19  137224                     Chateau Brillette
#
#                                       Nom           Region  Degre  Annee  Qte
# 0                                  Altair     Rapel Valley  14~15   2014  750
# 1                                  Altair     Rapel Valley  14~15   2016  750
# 2                            Baron du Val              NaN  11~12      0  750
# 3                            Baron du Val              NaN  11~12      0  750
# 4                                Benziger       California  13~14   2003  750
# 5                                  Calvet        Bourgogne     12   2007  750
# 6                                  Calvet         Bordeaux     13   2003  750
# 7                                  Calvet         Bordeaux  13~14   2011  750
# 8                                  Calvet         Bordeaux   11.5   2010  750
# 9                                  Calvet  Southern France  13~14   2017  750
# 10                                 Calvet  Southern France  13~14   2011  750
# 11                                 Calvet         Bordeaux   11.5   2011  750
# 12                                 Calvet         Bordeaux     13   2009  750
# 13                                 Calvet         Bordeaux   12.5   2004  750
# 14                                 Calvet         Bordeaux  12~13   2015  750
# 15                                 Calvet         Bordeaux  12~13   2010  750
# 16                        Caviro scaForli    EmiliaRomagna     11      0  750
# 17                        Caviro scaForli    EmiliaRomagna     11      0  750
# 18  Chateau Angelus 1st Grand Cru ClasseA         Bordeaux   13.5   2017  750
# 19                      Chateau Brillette         Bordeaux  13~14   2013  750

# %% [markdown]
# ### 4. Vérification des valeurs manquantes

# %%
print(df.isnull().sum())
# Out:
# Nvin         0
# Cru          0
# Nom          0
# Region     900
# Degre     7146
# Annee        0
# Qte          0
# dtype: int64

# %% [markdown]
# ### 5. Nettoyage et normalisation de la colonne Degre (Degré d’alcool)
# ###    Format attendu : float entre 5 et 15

# %%
def convert_Degre(val): 
    try:
        val = str(val).strip()
        if "~" in val:
            a, b = map(float, val.split("~"))
            return round((a + b) / 2, 1)
        return float(val)
    except:
        return np.nan

df["Degre"] = df["Degre"].apply(convert_Degre)
df["Degre"].fillna(12.5, inplace=True)
df = df[(df["Degre"] >= 5) & (df["Degre"] <= 15)]
print(df["Degre"].head(15))
# Out:
# 0     14.5
# 1     14.5
# 2     11.5
# 3     11.5
# 4     13.5
# 5     12.0
# 6     13.0
# 7     13.5
# 8     11.5
# 9     13.5
# 10    13.5
# 11    11.5
# 12    13.0
# 13    12.5
# 14    12.5
# Name: Degre, dtype: float64

# %%
print(df.isnull().sum())
# Out:
# Nvin        0
# Cru         0
# Nom         0
# Region    851
# Degre       0
# Annee       0
# Qte         0
# dtype: int64

# %% [markdown]
# ### 6. Traitement des valeurs manquantes dans Region

# %%
regions = ["Rhone", "Beaujolais", "Sud Ouest", "Jura"] 
df["Region"] = df["Region"].apply(lambda x: x if pd.notnull(x) else np.random.choice(regions))
print(df["Region"].head(15))
# Out:
# 0        Rapel Valley
# 1        Rapel Valley
# 2               Rhone
# 3               Rhone
# 4          California
# 5           Bourgogne
# 6            Bordeaux
# 7            Bordeaux
# 8            Bordeaux
# 9     Southern France
# 10    Southern France
# 11           Bordeaux
# 12           Bordeaux
# 13           Bordeaux
# 14           Bordeaux
# Name: Region, dtype: object

# %%
print(df.isnull().sum())
# Out:
# Nvin      0
# Cru       0
# Nom       0
# Region    0
# Degre     0
# Annee     0
# Qte       0
# dtype: int64

# %% [markdown]
# ### 7. Génération aléatoire de prénoms et d’identifiants producteurs (Nprod)

# %%
fake = Faker('fr_FR')
prenoms = [fake.first_name() for _ in range(len(df))]
nprods = range(130, 130 + len(df))
df["Prenom"] = prenoms
df["Nprod"]  = nprods
df.head(20)
# Out:
#       Nvin                                   Cru  \
# 0   137197                                Altair
# 1   137198                       Altair, Sideral
# 2   137199                      Baron du Val Red
# 3   137200                    Baron du Val White
# 4   137201          Benziger, Cabernet Sauvignon
# 5   137202           Calvet, Beaujolais Villages
# 6   137203                         Calvet, Aetos
# 7   137204                  Calvet, Bordeaux Red
# 8   137205                Calvet, Bordeaux white
# 9   137207  Calvet, Varietals Cabernet Sauvignon
# 10  137208              Calvet, Varietals Merlot
# 11  137209        Calvet, Reserve Bordeaux white
# 12  137210   Calvet, Premieres Cotes de Bordeaux
# 13  137211                       Calvet, Margaux
# 14  137212                         Calvet, Medoc
# 15  137214                 Calvet, Saint Emilion
# 16  137217           Tavernello Rosato Frizzante
# 17  137218            Tavernello Bianco Fizzante
# 18  137222              La Carillon de l'Angelus
# 19  137224                     Chateau Brillette
#
#                                       Nom           Region  Degre  Annee  Qte  \
# 0                                  Altair     Rapel Valley   14.5   2014  750
# 1                                  Altair     Rapel Valley   14.5   2016  750
# 2                            Baron du Val            Rhone   11.5      0  750
# 3                            Baron du Val            Rhone   11.5      0  750
# 4                                Benziger       California   13.5   2003  750
# 5                                  Calvet        Bourgogne   12.0   2007  750
# 6                                  Calvet         Bordeaux   13.0   2003  750
# 7                                  Calvet         Bordeaux   13.5   2011  750
# 8                                  Calvet         Bordeaux   11.5   2010  750
# 9                                  Calvet  Southern France   13.5   2017  750
# 10                                 Calvet  Southern France   13.5   2011  750
# 11                                 Calvet         Bordeaux   11.5   2011  750
# 12                                 Calvet         Bordeaux   13.0   2009  750
# 13                                 Calvet         Bordeaux   12.5   2004  750
# 14                                 Calvet         Bordeaux   12.5   2015  750
# 15                                 Calvet         Bordeaux   12.5   2010  750
# 16                        Caviro scaForli    EmiliaRomagna   11.0      0  750
# 17                        Caviro scaForli    EmiliaRomagna   11.0      0  750
# 18  Chateau Angelus 1st Grand Cru ClasseA         Bordeaux   13.5   2017  750
# 19                      Chateau Brillette         Bordeaux   13.5   2013  750
#
#         Prenom  Nprod
# 0     Bertrand    130
# 1       Eugène    131
# 2       Marine    132
# 3       Arthur    133
# 4     Victoire    134
# 5       Marine    135
# 6       Aurore    136
# 7       Xavier    137
# 8     Marcelle    138
# 9        Manon    139
# 10      Benoît    140
# 11        Paul    141
# 12      Maryse    142
# 13        Léon    143
# 14     Gilbert    144
# 15  Christiane    145
# 16    Matthieu    146
# 17    Philippe    147
# 18       Manon    148
# 19     Raymond    149

# %%
print(df.isnull().sum())
# Out:
# Nvin      0
# Cru       0
# Nom       0
# Region    0
# Degre     0
# Annee     0
# Qte       0
# Prenom    0
# Nprod     0
# dtype: int64

# %% [markdown]
# ### 8. Nettoyage de la colonne Annee : remplacer les 0 par une année valide

# %%
nb_zero = (df["Annee"] == 0).sum()
nb_zero
# Out:
# 2389

# %%
annees = [2020, 2019, 2018, 2017, 2016, 2015]
df["Annee"] = df["Annee"].apply(lambda x: np.random.choice(annees) if x == 0 else x) 
df.head(20)
# Out:
#       Nvin                                   Cru  \
# 0   137197                                Altair
# 1   137198                       Altair, Sideral
# 2   137199                      Baron du Val Red
# 3   137200                    Baron du Val White
# 4   137201          Benziger, Cabernet Sauvignon
# 5   137202           Calvet, Beaujolais Villages
# 6   137203                         Calvet, Aetos
# 7   137204                  Calvet, Bordeaux Red
# 8   137205                Calvet, Bordeaux white
# 9   137207  Calvet, Varietals Cabernet Sauvignon
# 10  137208              Calvet, Varietals Merlot
# 11  137209        Calvet, Reserve Bordeaux white
# 12  137210   Calvet, Premieres Cotes de Bordeaux
# 13  137211                       Calvet, Margaux
# 14  137212                         Calvet, Medoc
# 15  137214                 Calvet, Saint Emilion
# 16  137217           Tavernello Rosato Frizzante
# 17  137218            Tavernello Bianco Fizzante
# 18  137222              La Carillon de l'Angelus
# 19  137224                     Chateau Brillette
#
#                                       Nom           Region  Degre  Annee  Qte  \
# 0                                  Altair     Rapel Valley   14.5   2014  750
# 1                                  Altair     Rapel Valley   14.5   2016  750
# 2                            Baron du Val            Rhone   11.5   2015  750
# 3                            Baron du Val            Rhone   11.5   2017  750
# 4                                Benziger       California   13.5   2003  750
# 5                                  Calvet        Bourgogne   12.0   2007  750
# 6                                  Calvet         Bordeaux   13.0   2003  750
# 7                                  Calvet         Bordeaux   13.5   2011  750
# 8                                  Calvet         Bordeaux   11.5   2010  750
# 9                                  Calvet  Southern France   13.5   2017  750
# 10                                 Calvet  Southern France   13.5   2011  750
# 11                                 Calvet         Bordeaux   11.5   2011  750
# 12                                 Calvet         Bordeaux   13.0   2009  750
# 13                                 Calvet         Bordeaux   12.5   2004  750
# 14                                 Calvet         Bordeaux   12.5   2015  750
# 15                                 Calvet         Bordeaux   12.5   2010  750
# 16                        Caviro scaForli    EmiliaRomagna   11.0   2016  750
# 17                        Caviro scaForli    EmiliaRomagna   11.0   2019  750
# 18  Chateau Angelus 1st Grand Cru ClasseA         Bordeaux   13.5   2017  750
# 19                      Chateau Brillette         Bordeaux   13.5   2013  750
#
#         Prenom  Nprod
# 0     Bertrand    130
# 1       Eugène    131
# 2       Marine    132
# 3       Arthur    133
# 4     Victoire    134
# 5       Marine    135
# 6       Aurore    136
# 7       Xavier    137
# 8     Marcelle    138
# 9        Manon    139
# 10      Benoît    140
# 11        Paul    141
# 12      Maryse    142
# 13        Léon    143
# 14     Gilbert    144
# 15  Christiane    145
# 16    Matthieu    146
# 17    Philippe    147
# 18       Manon    148
# 19     Raymond    149

# %%
nb_zero = (df["Annee"] == 0).sum()
nb_zero
# Out:
# 0

# %% [markdown]
# ### 9. Traduction des noms de régions (anglais → français)

# %%
pip install googletrans==4.0.0-rc1
# Out:
# Requirement already satisfied: googletrans==4.0.0-rc1 in /opt/anaconda3/lib/python3.11/site-packages (4.0.0rc1)
# Requirement already satisfied: httpx==0.13.3 in /opt/anaconda3/lib/python3.11/site-packages (from googletrans==4.0.0-rc1) (0.13.3)
# Requirement already satisfied: certifi in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2024.2.2)
# Requirement already satisfied: hstspreload in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2025.1.1)
# Requirement already satisfied: sniffio in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.2.0)
# Requirement already satisfied: chardet==3.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.4)
# Requirement already satisfied: idna==2.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (2.10)
# Requirement already satisfied: rfc3986<2,>=1.3 in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (1.5.0)
# Requirement already satisfied: httpcore==0.9.* in /opt/anaconda3/lib/python3.11/site-packages (from httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.1)
# Requirement already satisfied: h11<0.10,>=0.8 in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (0.9.0)
# Requirement already satisfied: h2==3.* in /opt/anaconda3/lib/python3.11/site-packages (from httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.2.0)
# Requirement already satisfied: hyperframe<6,>=5.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (5.2.0)
# Requirement already satisfied: hpack<4,>=3.0 in /opt/anaconda3/lib/python3.11/site-packages (from h2==3.*->httpcore==0.9.*->httpx==0.13.3->googletrans==4.0.0-rc1) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
translator = Translator()

unique_regions = df["Region"].unique()

translations = {}
for reg in unique_regions:
    try:
        res = translator.translate(reg, src="en", dest="fr")
        translations[reg] = res.text        # .text c'est le texte traduit
    except Exception as e:
        translations[reg] = reg

df["Region"] = df["Region"].map(translations)

# %% [markdown]
# ### 10. Création des trois tables pour insertion dans Oracle

# %%
# Table VINR : identifiant vin, appellation, degré
df_vinr = df[["Nvin", "Cru", "Degre"]].drop_duplicates()
df_vinr.to_csv("vinR.csv", index=False)

# Table PRODUCTEURR : identifiant producteur, nom, prénom, région
df_producteurr = df[["Nprod", "Nom", "Prenom", "Region"]].drop_duplicates()
df_producteurr.to_csv("producteurR.csv", index=False)

# Table RECOLTER : relation producteur-vin avec année et quantité
df_recolter = df[["Nprod", "Nvin", "Annee", "Qte"]].drop_duplicates()
df_recolter.to_csv("recolteR.csv", index=False)

# %% [markdown]
# ### 11. Vérification finale

# %%
print("Aperçu VINR :")
print(df_vinr.head(10))
print("\nAperçu PRODUCTEURR :")
print(df_producteurr.head(10))
print("\nAperçu RECOLTER :")
print(df_recolter.head(10))
# Out:
# Aperçu VINR :
#      Nvin                                   Cru  Degre
# 0  137197                                Altair   14.5
# 1  137198                       Altair, Sideral   14.5
# 2  137199                      Baron du Val Red   11.5
# 3  137200                    Baron du Val White   11.5
# 4  137201          Benziger, Cabernet Sauvignon   13.5
# 5  137202           Calvet, Beaujolais Villages   12.0
# 6  137203                         Calvet, Aetos   13.0
# 7  137204                  Calvet, Bordeaux Red   13.5
# 8  137205                Calvet, Bordeaux white   11.5
# 9  137207  Calvet, Varietals Cabernet Sauvignon   13.5
#
# Aperçu PRODUCTEURR :
#    Nprod           Nom    Prenom            Region
# 0    130        Altair  Bertrand     Vallée du vif
# 1    131        Altair    Eugène     Vallée du vif
# 2    132  Baron du Val    Marine             Rhône
# 3    133  Baron du Val    Arthur             Rhône
# 4    134      Benziger  Victoire        Californie
# 5    135        Calvet    Marine         Bourgogne
# 6    136        Calvet    Aurore          Bordeaux
# 7    137        Calvet    Xavier          Bordeaux
# 8    138        Calvet  Marcelle          Bordeaux
# 9    139        Calvet     Manon  Sud de la France
#
# Aperçu RECOLTER :
#    Nprod    Nvin  Annee  Qte
# 0    130  137197   2014  750
# 1    131  137198   2016  750
# 2    132  137199   2015  750
# 3    133  137200   2017  750
# 4    134  137201   2003  750
# 5    135  137202   2007  750
# 6    136  137203   2003  750
# 7    137  137204   2011  750
# 8    138  137205   2010  750
# 9    139  137207   2017  750
